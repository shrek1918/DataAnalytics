# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y1=[12,14,15,16,6]
y2=[21,24,12,5,7]
y3=[5,12,16,10,6]
plt.figure(figsize=[5,3])
plt.plot(x,y1,label="Men")
plt.plot(x,y2, label="Women")
plt.plot(x,y3, label="Kids")
# plt.legend(["a1","a2","a3"],ncols=2)
plt.legend(bbox_to_anchor =(1.30,1.03))
plt.show()
