# %%
import matplotlib.pyplot as plt
x=["day1","day2","day3","day4","day5"]
y=[30,40,20,60,35]
plt.step(x,y,where="mid",marker="o")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
dataset=pd.read_excel("expense3.xlsx")
df["Category"]=df["Category"].replace(123,"Miscallaneous")
grouped=df.groupby("Category").agg({"Amount":"sum"})
plt.step(grouped.index,grouped["Amount"],where="mid",marker="o")
plt.show()
